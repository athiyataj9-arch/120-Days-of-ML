# %% [markdown]
# #Naive Bayes
#
# **Logic:** "Probability-based guessing." It calculates the probability of a feature belonging to a class based on past data.

# %% [markdown]
# #Imports & Dataset

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.3, random_state=42)

# %% [markdown]
# #Training & Prediction

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)

y_pred = gnb.predict(X_test)
print(f"Naive Bayes Accuracy: {accuracy_score(y_test, y_pred)*100:.2f}%")
# Out:
# Naive Bayes Accuracy: 97.78%
