# %% [markdown]
# #RandomizedSearchCV (The Faster Alternative)
#
# **The Goal:** If your grid is too big, GridSearchCV takes forever. RandomizedSearchCV picks random combinations, which usually finds the "good enough" parameters much faster.

# %% [markdown]
# #Imports & Data

# %%
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# %% [markdown]
# #Random Search Implementation

# %%
param_dist = {
    'n_estimators': randint(50, 200),
    'max_depth': [3, 10, None]
}

random_search = RandomizedSearchCV(RandomForestClassifier(), param_distributions=param_dist, n_iter=5, cv=3)
random_search.fit(X_train, y_train)
print(f"Best Random Params: {random_search.best_params_}")
# Out:
# Best Random Params: {'max_depth': None, 'n_estimators': 144}
