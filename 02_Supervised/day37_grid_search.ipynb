# %% [markdown]
# #Hyperparameter Tuning (GridSearchCV)
#
# **The Goal:** Instead of guessing the best parameters (like max_depth), we create a "grid" of options and let the computer test every combination to find the winner.

# %% [markdown]
# #The Search Grid

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %% [markdown]
# #Setup Data

# %%
data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2, random_state=42)

# %% [markdown]
# #Define the parameters we want to test

# %%
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5]
}

# %% [markdown]
# #Initialize GridSearchCV

# %%
grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42), 
                           param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)

grid_search.fit(X_train, y_train)

print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Score: {grid_search.best_score_*100:.2f}%")
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Best Parameters: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 50}
# Best Score: 95.82%
