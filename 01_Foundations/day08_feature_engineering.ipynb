# %% [markdown]
# #Feature Engineering (Scaling)
#
# Goal: Scale data so features don't dominate the model based on size (e.g., salary vs. age).

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

data = np.array([[25, 50000], [30, 60000], [35, 75000]])

# Standardization (Makes mean=0, std=1)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

print("Scaled Data:\n", scaled_data)
# Out:
# Scaled Data:
#  [[-1.22474487 -1.13554995]
#  [ 0.         -0.16222142]
#  [ 1.22474487  1.29777137]]
