# %% [markdown]
# #Linear Algebra (Matrix Math)
#
# Goal: Understand how data is multiplied in Neural Networks.

# %%
import numpy as np

# 1. Dot Product (Weighted sums in models)
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
print("Dot Product:", np.dot(a, b))

# 2. Matrix Multiplication (The core of Deep Learning)
matrix_a = np.array([[1, 2], [3, 4]])
matrix_b = np.array([[5, 6], [7, 8]])
result = np.matmul(matrix_a, matrix_b)

print("\nMatrix Product:\n", result)
# Out:
# Dot Product: 32
#
# Matrix Product:
#  [[19 22]
#  [43 50]]
