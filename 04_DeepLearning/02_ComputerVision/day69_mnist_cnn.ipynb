# %% [markdown]
# #First CNN (MNIST Digit Classifier)
#
# **Logic:** A regular "Dense" network would flatten the image and lose the spatial relationship between pixels. A CNN looks at the image in 2D, recognizing that a "circle" shape usually means a 0 or an 8, regardless of where it is in the box.

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist

# 1. Load and Preprocess the Data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Reshape to (28, 28, 1) because CNNs expect 4D input: (batch, height, width, channels)
train_images = train_images.reshape((60000, 28, 28, 1)).astype('float32') / 255
test_images = test_images.reshape((10000, 28, 28, 1)).astype('float32') / 255

# 2. Build the CNN Architecture
model = models.Sequential([
    # Layer 1: Convolution (Finding edges/curves)
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    layers.MaxPooling2D((2, 2)), # Shrinking the image
    
    # Layer 2: Convolution (Finding complex shapes)
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    # Layer 3: Transition to Classification
    layers.Flatten(), # Flatten 2D images into a 1D vector
    layers.Dense(64, activation='relu'),
    layers.Dense(10, activation='softmax') # 10 neurons for digits 0-9
])

# 3. Compile and Train
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print("Day 69: Training the Digit Reader...")
model.fit(train_images, train_labels, epochs=5, batch_size=64)

# 4. Evaluate
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"\n✅ Test Accuracy: {test_acc*100:.2f}%")
# Out:
# Day 69: Training the Digit Reader...
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9446 - loss: 0.1893
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9826 - loss: 0.0554
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9881 - loss: 0.0383
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9904 - loss: 0.0299
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 11s 12ms/step - accuracy: 0.9923 - loss: 0.0233
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9888 - loss: 0.0327
#
# ✅ Test Accuracy: 98.88%
